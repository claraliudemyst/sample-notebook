# %%
import pandas as pd
import csv
from demyst.analytics import Analytics
from collections import Counter
import numpy as np

# %% [markdown]
# # Single Sign On / SAML

# %% [markdown]
# First, you need to login to the Demyst Console through the SSO link your company provides. Once you are authenticated, click the "API Key" button in the menubar and copy the token into your clipboard. Place the token in the JWT field and your email address in the username field.

# %%
analytics = Analytics(username="REPLACE WTIH EMAIL ADDRESS", jwt="REPLACE WTIH KEY")

# %% [markdown]
# # Read In Your Input Data File

# %%
inputs = pd.read_csv('https://demyst-apis.s3.amazonaws.com/demos/all_reg_no.csv', header = None)
inputs.columns = ['company_number']
inputs['client_id'] =  inputs.index

# %% [markdown]
# # List All Of The Relevant Providers For This Use Case

# %%
all_providers = ['acuris_business_search', 
                 'companies_house_company_officers',
                 'companies_house_company_profile',
                 'duedil_company_charges', 
                 'duedil_company_group_parents',
                 'duedil_company_group_subsidiaries',
                 'duedil_company_officers',
                 'duedil_company_related_companies',
                 'duedil_company_vitals',
                 'duedil_find_company',
                 'globaldatabase_company_details',
                 'globaldatabase_find_companies',
                 'matchdeck_search',
                 'matchdeck_details',
                 'opencorporates_companies_search',
                 'orb_search',
                 'owler_company_premium',
                 'pipl_premium_search']

# %% [markdown]
# # Get Company Name and Address through Companies House

# %%
providers = ['companies_house_company_profile', 'companies_house_company_officers']

company_basic = analytics.enrich_and_download(providers, inputs, validate=False)

company_basic.rename(columns = {'companies_house_company_profile.client_id': 'client_id',
                                'inputs.company_number': 'company_number'},inplace = True)
company_basic.head()
# Out:
# Verifying providers...
# Starting enrichment...
# Uploading data...
# This enrichment will use 0.1 credits of the 998063049 credits your organization currently has.
# Enrich Job ID: 6169
# IntProgress(value=1, max=2)
# Label(value='Checking status...')
#   company_number  companies_house_company_profile.row_id  client_id  \
# 0       SC005364                                       0          0
# 1       09797821                                       1          1
# 2       09631707                                       2          2
# 3       SC036374                                       3          3
# 4       08802727                                       4          4
#
#    companies_house_company_profile.accounts.accounting_reference_date.day  \
# 0                                                 30
# 1                                                 30
# 2                                                 31
# 3                                                 31
# 4                                                 31
#
#    companies_house_company_profile.accounts.accounting_reference_date.month  \
# 0                                                  6
# 1                                                  9
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#   companies_house_company_profile.accounts.last_accounts.made_up_to  \
# 0                                         2018-06-30
# 1                                         2017-09-30
# 2                                         2018-03-31
# 3                                         2018-03-31
# 4                                         2018-03-31
#
#   companies_house_company_profile.accounts.last_accounts.period_end_on  \
# 0                                         2018-06-30
# 1                                         2017-09-30
# 2                                         2018-03-31
# 3                                         2018-03-31
# 4                                         2018-03-31
#
#   companies_house_company_profile.accounts.last_accounts.period_start_on  \
# 0                                         2017-07-01
# 1                                         2016-10-01
# 2                                         2017-04-01
# 3                                         2017-04-01
# 4                                         2017-04-01
#
#   companies_house_company_profile.accounts.last_accounts.type  \
# 0                                              group
# 1                                       micro-entity
# 2                                              group
# 3                                              group
# 4                                              group
#
#   companies_house_company_profile.accounts.next_accounts.due_on  ...  \
# 0                                         2019-12-31             ...
# 1                                         2019-06-30             ...
# 2                                         2019-12-31             ...
# 3                                         2019-12-31             ...
# 4                                         2019-12-31             ...
#
#    companies_house_company_officers.items[9].occupation  \
# 0                                Commercial Director
# 1
# 2                           Private Equity Executive
# 3
# 4                                       Master Baker
#
#   companies_house_company_officers.items[9].officer_role  \
# 0                                           director
# 1
# 2                                           director
# 3                                          secretary
# 4                                           director
#
#   companies_house_company_officers.items[9].resigned_on  \
# 0
# 1
# 2                                         2018-04-01
# 3                                         1997-07-01
# 4                                         2016-10-14
#
#   companies_house_company_officers.items_per_page  \
# 0                                              35
# 1                                              35
# 2                                              35
# 3                                              35
# 4                                              35
#
#   companies_house_company_officers.kind  \
# 0                          officer-list
# 1                          officer-list
# 2                          officer-list
# 3                          officer-list
# 4                          officer-list
#
#    companies_house_company_officers.links.self  \
# 0                   /company/SC005364/officers
# 1                   /company/09797821/officers
# 2                   /company/09631707/officers
# 3                   /company/SC036374/officers
# 4                   /company/08802727/officers
#
#    companies_house_company_officers.resigned_count  \
# 0                                               23
# 1                                                4
# 2                                                3
# 3                                               18
# 4                                                6
#
#   companies_house_company_officers.start_index  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#   companies_house_company_officers.total_results  \
# 0                                             33
# 1                                              8
# 2                                             11
# 3                                             26
# 4                                             14
#
#   companies_house_company_officers.error
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 624 columns]

# %% [markdown]
# # Add Returned Company Name And Address To Input File

# %%
# Mapping county to region(state) ISO code
county_code= pd.read_excel('https://demyst-apis.s3.amazonaws.com/demos/county_code.xlsx')
code = {}
for i in range(len(county_code)):
    code[county_code['county'][i].lower().strip()] = county_code['parent'][i]
    
def find_code(x):
    if x != x:
        return ''
    if type(x) is str and x.lower() in code.keys():
        return code[x.lower()]
    else:
        return ''

# %%
inputs['business_name'] = company_basic['companies_house_company_profile.company_name']
inputs['country'] = 'UK'
inputs['name'] = inputs['business_name']
inputs['search_term'] = inputs['business_name']
inputs['street'] = company_basic['companies_house_company_profile.registered_office_address.address_line_1']
inputs['city'] = company_basic['companies_house_company_profile.registered_office_address.locality']
inputs['post_code'] = company_basic['companies_house_company_profile.registered_office_address.postal_code']
inputs['state'] = company_basic['companies_house_company_profile.registered_office_address.locality'].apply(lambda x: find_code(x))
inputs.fillna('', inplace = True)

# %%
inputs.head()
# Out:
#   company_number  client_id                       business_name country  \
# 0       SC005364          0          Aberdeen Football Club Plc      UK
# 1       09797821          1                   Freetrade Limited      UK
# 2       09631707          2         Erm Worldwide Group Limited      UK
# 3       SC036374          3         The Edrington Group Limited      UK
# 4       08802727          4  Bako North Western (group) Limited      UK
#
#                                  name                         search_term  \
# 0          Aberdeen Football Club Plc          Aberdeen Football Club Plc
# 1                   Freetrade Limited                   Freetrade Limited
# 2         Erm Worldwide Group Limited         Erm Worldwide Group Limited
# 3         The Edrington Group Limited         The Edrington Group Limited
# 4  Bako North Western (group) Limited  Bako North Western (group) Limited
#
#                            street      city post_code state
# 0               Pittodrie Stadium  Aberdeen  AB24 5QH   SCT
# 1                     Second Home    London    E1 5JL   ENG
# 2       2nd Floor Exchequer Court    London  EC3A 8AA   ENG
# 3                100 Queen Street   Glasgow    G1 3DN   SCT
# 4  74 Roman Way Industrial Estate   Preston   PR2 5BE

# %% [markdown]
# # Execute First Stage Of Appends - Vendors Which Use Company Name And Address As Input

# %%
providers = [
             'duedil_find_company',
             'acuris_business_search', 
             'globaldatabase_find_companies',
             'opencorporates_companies_search',
             'matchdeck_search',
             'orb_search'
             ]

# %%
first_results = analytics.enrich_and_download(providers, inputs, validate=False)
first_results.head()
# Out:
# Verifying providers...
# Starting enrichment...
# Uploading data...
# This enrichment will use 0.95 credits of the 998063049 credits your organization currently has.
# Enrich Job ID: 6170
# IntProgress(value=1, max=2)
# Label(value='Checking status...')
#                  inputs.business_name inputs.city inputs.company_number  \
# 0          Aberdeen Football Club Plc    Aberdeen              SC005364
# 1                   Freetrade Limited      London              09797821
# 2         Erm Worldwide Group Limited      London              09631707
# 3         The Edrington Group Limited     Glasgow              SC036374
# 4  Bako North Western (group) Limited     Preston              08802727
#
#   inputs.country                         inputs.name inputs.post_code  \
# 0             UK          Aberdeen Football Club Plc         AB24 5QH
# 1             UK                   Freetrade Limited           E1 5JL
# 2             UK         Erm Worldwide Group Limited         EC3A 8AA
# 3             UK         The Edrington Group Limited           G1 3DN
# 4             UK  Bako North Western (group) Limited          PR2 5BE
#
#                    inputs.search_term inputs.state  \
# 0          Aberdeen Football Club Plc          SCT
# 1                   Freetrade Limited          ENG
# 2         Erm Worldwide Group Limited          ENG
# 3         The Edrington Group Limited          SCT
# 4  Bako North Western (group) Limited
#
#                     inputs.street  duedil_find_company.row_id  ...  \
# 0               Pittodrie Stadium                           0  ...
# 1                     Second Home                           1  ...
# 2       2nd Floor Exchequer Court                           2  ...
# 3                100 Queen Street                           3  ...
# 4  74 Roman Way Industrial Estate                           4  ...
#
#    orb_search.results[9].orb_num orb_search.results[9].parent_name  \
# 0
# 1                       96116834
# 2                       96116834
# 3
# 4                       14301100
#
#   orb_search.results[9].parent_orb_num orb_search.results[9].state  \
# 0
# 1                                                              ENG
# 2                                                              ENG
# 3
# 4                                                       Lancashire
#
#   orb_search.results[9].subsidiaries_count  \
# 0
# 1                                        0
# 2                                        0
# 3
# 4                                        0
#
#   orb_search.results[9].ultimate_parent_name  \
# 0
# 1
# 2
# 3
# 4
#
#   orb_search.results[9].ultimate_parent_orb_num orb_search.results[9].zip  \
# 0
# 1                                                                 E14 5AP
# 2                                                                 E14 5AP
# 3
# 4                                                                 PR2 8UR
#
#   orb_search.results_count orb_search.error
# 0                        0
# 1                       17
# 2                       17
# 3                        0
# 4                    15365
#
# [5 rows x 21675 columns]

# %% [markdown]
# #### Merge the returned results against unique client ID

# %%
results = pd.merge(company_basic, first_results, how = 'left',left_on = 'client_id', right_on = 'duedil_find_company.client_id')
results.head()
# Out:
#   company_number  companies_house_company_profile.row_id  client_id  \
# 0       SC005364                                       0          0
# 1       09797821                                       1          1
# 2       09631707                                       2          2
# 3       SC036374                                       3          3
# 4       08802727                                       4          4
#
#    companies_house_company_profile.accounts.accounting_reference_date.day  \
# 0                                                 30
# 1                                                 30
# 2                                                 31
# 3                                                 31
# 4                                                 31
#
#    companies_house_company_profile.accounts.accounting_reference_date.month  \
# 0                                                  6
# 1                                                  9
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#   companies_house_company_profile.accounts.last_accounts.made_up_to  \
# 0                                         2018-06-30
# 1                                         2017-09-30
# 2                                         2018-03-31
# 3                                         2018-03-31
# 4                                         2018-03-31
#
#   companies_house_company_profile.accounts.last_accounts.period_end_on  \
# 0                                         2018-06-30
# 1                                         2017-09-30
# 2                                         2018-03-31
# 3                                         2018-03-31
# 4                                         2018-03-31
#
#   companies_house_company_profile.accounts.last_accounts.period_start_on  \
# 0                                         2017-07-01
# 1                                         2016-10-01
# 2                                         2017-04-01
# 3                                         2017-04-01
# 4                                         2017-04-01
#
#   companies_house_company_profile.accounts.last_accounts.type  \
# 0                                              group
# 1                                       micro-entity
# 2                                              group
# 3                                              group
# 4                                              group
#
#   companies_house_company_profile.accounts.next_accounts.due_on  ...  \
# 0                                         2019-12-31             ...
# 1                                         2019-06-30             ...
# 2                                         2019-12-31             ...
# 3                                         2019-12-31             ...
# 4                                         2019-12-31             ...
#
#    orb_search.results[9].orb_num orb_search.results[9].parent_name  \
# 0
# 1                       96116834
# 2                       96116834
# 3
# 4                       14301100
#
#   orb_search.results[9].parent_orb_num orb_search.results[9].state  \
# 0
# 1                                                              ENG
# 2                                                              ENG
# 3
# 4                                                       Lancashire
#
#   orb_search.results[9].subsidiaries_count  \
# 0
# 1                                        0
# 2                                        0
# 3
# 4                                        0
#
#    orb_search.results[9].ultimate_parent_name  \
# 0
# 1
# 2
# 3
# 4
#
#    orb_search.results[9].ultimate_parent_orb_num orb_search.results[9].zip  \
# 0
# 1                                                                  E14 5AP
# 2                                                                  E14 5AP
# 3
# 4                                                                  PR2 8UR
#
#   orb_search.results_count orb_search.error
# 0                        0
# 1                       17
# 2                       17
# 3                        0
# 4                    15365
#
# [5 rows x 22299 columns]

# %% [markdown]
# # Execute Second Stage Of Appends - Sources Which Require More Inputs

# %% [markdown]
# #### Create Input for Pipl

# %%
#Create PIPL input to enable matching against unique client ID
pipl_input = inputs[['client_id','country']].copy()
pipl_input['street'] = company_basic['companies_house_company_officers.items[0].address.address_line_1']
pipl_input['city'] = company_basic['companies_house_company_officers.items[0].address.locality']
pipl_input['post_code'] = company_basic['companies_house_company_officers.items[0].address.postal_code']
pipl_input['state'] = company_basic['companies_house_company_officers.items[0].address.locality'].apply(lambda x:find_code(x))
pipl_input['first_name'] = company_basic['companies_house_company_officers.items[0].name'].apply(lambda x: x.split()[0] if x==x else '')
pipl_input['last_name'] = company_basic['companies_house_company_officers.items[0].name'].apply(lambda x: x.split()[-1] if x==x else '')
pipl_input.fillna('', inplace = True)
pipl_input.head()
# Out:
#    client_id country                       street      city post_code state  \
# 0          0      UK            Pittodrie Stadium  Aberdeen  AB24 5QH   SCT
# 1          1      UK            68 Hanbury Street    London    E1 5JL   ENG
# 2          2      UK              Exchequer Court    London  EC3A 8AA   ENG
# 3          3      UK                 Queen Street   Glasgow    G1 3DN   SCT
# 4          4      UK  Roman Way Industrial Estate   Preston   PR2 5BE
#
#   first_name last_name
# 0        Roy  Johnston
# 1     Daniel    Tedman
# 2        Roy   Burrows
# 3     Martin     Cooke
# 4      Kirti    Hirani

# %% [markdown]
# #### Run Pipl and Merge Results

# %%
pipl_results = analytics.enrich_and_download(['pipl_premium_search'], pipl_input[0:1], validate=False)
results = pd.merge(results, pipl_results, how = 'left',left_on = 'client_id', right_on = 'pipl_premium_search.client_id')
# Out:
# Verifying providers...
# Starting enrichment...
# Uploading data...
# This enrichment will use 5.5 credits of the 998063049 credits your organization currently has.
# Enrich Job ID: 6171
# IntProgress(value=1, max=2)
# Label(value='Checking status...')

# %%
results.head()
# Out:
#   company_number  companies_house_company_profile.row_id  client_id  \
# 0       SC005364                                       0          0
# 1       09797821                                       1          1
# 2       09631707                                       2          2
# 3       SC036374                                       3          3
# 4       08802727                                       4          4
#
#    companies_house_company_profile.accounts.accounting_reference_date.day  \
# 0                                                 30
# 1                                                 30
# 2                                                 31
# 3                                                 31
# 4                                                 31
#
#    companies_house_company_profile.accounts.accounting_reference_date.month  \
# 0                                                  6
# 1                                                  9
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#   companies_house_company_profile.accounts.last_accounts.made_up_to  \
# 0                                         2018-06-30
# 1                                         2017-09-30
# 2                                         2018-03-31
# 3                                         2018-03-31
# 4                                         2018-03-31
#
#   companies_house_company_profile.accounts.last_accounts.period_end_on  \
# 0                                         2018-06-30
# 1                                         2017-09-30
# 2                                         2018-03-31
# 3                                         2018-03-31
# 4                                         2018-03-31
#
#   companies_house_company_profile.accounts.last_accounts.period_start_on  \
# 0                                         2017-07-01
# 1                                         2016-10-01
# 2                                         2017-04-01
# 3                                         2017-04-01
# 4                                         2017-04-01
#
#   companies_house_company_profile.accounts.last_accounts.type  \
# 0                                              group
# 1                                       micro-entity
# 2                                              group
# 3                                              group
# 4                                              group
#
#   companies_house_company_profile.accounts.next_accounts.due_on  ...  \
# 0                                         2019-12-31             ...
# 1                                         2019-06-30             ...
# 2                                         2019-12-31             ...
# 3                                         2019-12-31             ...
# 4                                         2019-12-31             ...
#
#    pipl_premium_search.query.names[0].last_seen  \
# 0
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   pipl_premium_search.query.names[0].middle_name  \
# 0
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   pipl_premium_search.query.names[0].prefix  \
# 0
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   pipl_premium_search.query.names[0].suffix  \
# 0
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   pipl_premium_search.query.names[0].type  \
# 0
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    pipl_premium_search.query.names[0].valid_since  \
# 0
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    pipl_premium_search.query.search_pointer  \
# 0
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#            pipl_premium_search.search_id pipl_premium_search.visible_sources  \
# 0  1905302101092615289220499064332010274                                 0.0
# 1                                    NaN                                 NaN
# 2                                    NaN                                 NaN
# 3                                    NaN                                 NaN
# 4                                    NaN                                 NaN
#
#   pipl_premium_search.error
# 0
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
# [5 rows x 22387 columns]

# %% [markdown]
# #### Run DueDil and Merge Results

# %%
try:
    duedil_input = results[results['duedil_find_company.companies[0].company_id'].isna() == False][['duedil_find_company.client_id','duedil_find_company.companies[0].company_id']]
    duedil_input.rename(columns = {'duedil_find_company.client_id':'client_id',
                               'duedil_find_company.companies[0].company_id':'id'}, inplace = True)
    duedil_results = analytics.enrich_and_download(['duedil_company_vitals',
                                      'duedil_company_charges',
                                      'duedil_company_related_companies',
                                      'duedil_company_group_parents', 
                                      'duedil_company_group_subsidiaries', 
                                      'duedil_company_officers'], duedil_input, validate=False)
    results = pd.merge(results, duedil_results, how = 'left',left_on = 'client_id', right_on = 'duedil_company_vitals.client_id')
except:
    print('No company found for Duedil')
# Out:
# Verifying providers...
# Starting enrichment...
# Uploading data...
# This enrichment will use 0.3 credits of the 998063044 credits your organization currently has.
# Enrich Job ID: 6172
# IntProgress(value=1, max=2)
# Label(value='Checking status...')

# %%
results.head()
# Out:
#   company_number  companies_house_company_profile.row_id  client_id  \
# 0       SC005364                                       0          0
# 1       09797821                                       1          1
# 2       09631707                                       2          2
# 3       SC036374                                       3          3
# 4       08802727                                       4          4
#
#    companies_house_company_profile.accounts.accounting_reference_date.day  \
# 0                                                 30
# 1                                                 30
# 2                                                 31
# 3                                                 31
# 4                                                 31
#
#    companies_house_company_profile.accounts.accounting_reference_date.month  \
# 0                                                  6
# 1                                                  9
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#   companies_house_company_profile.accounts.last_accounts.made_up_to  \
# 0                                         2018-06-30
# 1                                         2017-09-30
# 2                                         2018-03-31
# 3                                         2018-03-31
# 4                                         2018-03-31
#
#   companies_house_company_profile.accounts.last_accounts.period_end_on  \
# 0                                         2018-06-30
# 1                                         2017-09-30
# 2                                         2018-03-31
# 3                                         2018-03-31
# 4                                         2018-03-31
#
#   companies_house_company_profile.accounts.last_accounts.period_start_on  \
# 0                                         2017-07-01
# 1                                         2016-10-01
# 2                                         2017-04-01
# 3                                         2017-04-01
# 4                                         2017-04-01
#
#   companies_house_company_profile.accounts.last_accounts.type  \
# 0                                              group
# 1                                       micro-entity
# 2                                              group
# 3                                              group
# 4                                              group
#
#   companies_house_company_profile.accounts.next_accounts.due_on  ...  \
# 0                                         2019-12-31             ...
# 1                                         2019-06-30             ...
# 2                                         2019-12-31             ...
# 3                                         2019-12-31             ...
# 4                                         2019-12-31             ...
#
#    duedil_company_officers.officers[9].person.honorific  \
# 0                                                 Mr
# 1
# 2                                                 Mr
# 3                                                 Mr
# 4                                                 Mr
#
#   duedil_company_officers.officers[9].person.last_name  \
# 0                                               Yule
# 1
# 2                                            Doherty
# 3                                           Macphail
# 4                                             Taylor
#
#   duedil_company_officers.officers[9].person.middle_name  \
# 0                                             Kynoch
# 1
# 2
# 3                                     Alexander Rose
# 4                                            Anthony
#
#   duedil_company_officers.officers[9].person.nationalities[0].country_code  \
# 0                                                 GB
# 1
# 2                                                 US
# 3                                                 GB
# 4                                                 GB
#
#   duedil_company_officers.officers[9].person.nationalities[0].demonym  \
# 0                                            British
# 1
# 2                                           American
# 3                                            British
# 4                                            British
#
#    duedil_company_officers.officers[9].type  \
# 0                                    person
# 1
# 2                                    person
# 3                                    person
# 4                                    person
#
#    duedil_company_officers.pagination.limit  \
# 0                                        10
# 1                                        10
# 2                                        10
# 3                                        10
# 4                                        10
#
#   duedil_company_officers.pagination.offset  \
# 0                                         0
# 1                                         0
# 2                                         0
# 3                                         0
# 4                                         0
#
#   duedil_company_officers.pagination.total duedil_company_officers.error
# 0                                       30
# 1                                        8
# 2                                       11
# 3                                       24
# 4                                       14
#
# [5 rows x 22984 columns]

# %% [markdown]
# #### Run GlobalDatabase And Merge Results

# %%
try:
    globaldatabase_input = results[results['globaldatabase_find_companies.companies[0].id'].isna() == False][['globaldatabase_find_companies.client_id','globaldatabase_find_companies.companies[0].id']]
    globaldatabase_input.rename(columns = {'globaldatabase_find_companies.client_id':'client_id',
                               'globaldatabase_find_companies.companies[0].id':'id'}, inplace = True)
    globaldatabase_results = analytics.enrich_and_download(['globaldatabase_company_details'], globaldatabase_input, validate=False)
    results = pd.merge(results, globaldatabase_results, how = 'left',left_on = 'client_id', right_on = 'globaldatabase_company_details.client_id')
except:
    print('No company found for global database')
# Out:
# Verifying providers...
# Starting enrichment...
# Uploading data...
# This enrichment will use 0.05 credits of the 998063044 credits your organization currently has.
# Enrich Job ID: 6173
# IntProgress(value=1, max=2)
# Label(value='Checking status...')

# %%
results.head()
# Out:
#   company_number  companies_house_company_profile.row_id  client_id  \
# 0       SC005364                                       0          0
# 1       09797821                                       1          1
# 2       09631707                                       2          2
# 3       SC036374                                       3          3
# 4       08802727                                       4          4
#
#    companies_house_company_profile.accounts.accounting_reference_date.day  \
# 0                                                 30
# 1                                                 30
# 2                                                 31
# 3                                                 31
# 4                                                 31
#
#    companies_house_company_profile.accounts.accounting_reference_date.month  \
# 0                                                  6
# 1                                                  9
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#   companies_house_company_profile.accounts.last_accounts.made_up_to  \
# 0                                         2018-06-30
# 1                                         2017-09-30
# 2                                         2018-03-31
# 3                                         2018-03-31
# 4                                         2018-03-31
#
#   companies_house_company_profile.accounts.last_accounts.period_end_on  \
# 0                                         2018-06-30
# 1                                         2017-09-30
# 2                                         2018-03-31
# 3                                         2018-03-31
# 4                                         2018-03-31
#
#   companies_house_company_profile.accounts.last_accounts.period_start_on  \
# 0                                         2017-07-01
# 1                                         2016-10-01
# 2                                         2017-04-01
# 3                                         2017-04-01
# 4                                         2017-04-01
#
#   companies_house_company_profile.accounts.last_accounts.type  \
# 0                                              group
# 1                                       micro-entity
# 2                                              group
# 3                                              group
# 4                                              group
#
#   companies_house_company_profile.accounts.next_accounts.due_on  ...  \
# 0                                         2019-12-31             ...
# 1                                         2019-06-30             ...
# 2                                         2019-12-31             ...
# 3                                         2019-12-31             ...
# 4                                         2019-12-31             ...
#
#    globaldatabase_company_details.location  \
# 0                         PITTODRIE STREET
# 1
# 2                              ST MARY AXE
# 3                                  GLASGOW
# 4                           LONGRIDGE ROAD
#
#   globaldatabase_company_details.phone  \
# 0                         441224650400
# 1
# 2
# 3
# 4                         448438164618
#
#   globaldatabase_company_details.post_code  \
# 0                                 AB24 5QH
# 1
# 2                                 EC3A 8AA
# 3                                   G1 3DN
# 4                                  PR2 5BE
#
#   globaldatabase_company_details.region  \
# 0                              Aberdeen
# 1
# 2                                London
# 3
# 4                               Preston
#
#   globaldatabase_company_details.registration_number  \
# 0                                           SC005364
# 1
# 2                                           09631707
# 3                                           SC036374
# 4                                           08802727
#
#    globaldatabase_company_details.size  globaldatabase_company_details.street  \
# 0                                                           Pittodrie Stadium
# 1
# 2                                                   2nd Floor Exchequer Court
# 3                                                            100 Queen Street
# 4                                              74 Roman Way Industrial Estate
#
#   globaldatabase_company_details.vat_number  \
# 0
# 1
# 2
# 3
# 4
#
#   globaldatabase_company_details.website  \
# 0                       http://afc.co.uk
# 1
# 2
# 3              http://edringtongroup.com
# 4              http://callbakolondon.com
#
#                 globaldatabase_company_details.error
# 0
# 1  type: insufficient_input , message: Inputs are...
# 2
# 3
# 4
#
# [5 rows x 23005 columns]

# %% [markdown]
# #### Run Owler And Merge Results

# %%
try:
    owler_input = results[results['globaldatabase_company_details.website'].isna() == False][['globaldatabase_company_details.client_id','globaldatabase_company_details.website']]
    owler_input.rename(columns = {'globaldatabase_company_details.client_id':'client_id',
                               'globaldatabase_company_details.website':'url'}, inplace = True)
    owler_results = analytics.enrich_and_download(['owler_company_premium'], owler_input, validate=False)
    results = pd.merge(results, owler_results, how = 'left',left_on = 'client_id', right_on = 'owler_company_premium.client_id')
except:
    print('No company found for Owler')
# Out:
# Verifying providers...
# Starting enrichment...
# Uploading data...
# This enrichment will use 20.5 credits of the 998063044 credits your organization currently has.
# Enrich Job ID: 6174
# IntProgress(value=1, max=2)
# Label(value='Checking status...')

# %%
results.head()
# Out:
#   company_number  companies_house_company_profile.row_id  client_id  \
# 0       SC005364                                       0          0
# 1       09797821                                       1          1
# 2       09631707                                       2          2
# 3       SC036374                                       3          3
# 4       08802727                                       4          4
#
#    companies_house_company_profile.accounts.accounting_reference_date.day  \
# 0                                                 30
# 1                                                 30
# 2                                                 31
# 3                                                 31
# 4                                                 31
#
#    companies_house_company_profile.accounts.accounting_reference_date.month  \
# 0                                                  6
# 1                                                  9
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#   companies_house_company_profile.accounts.last_accounts.made_up_to  \
# 0                                         2018-06-30
# 1                                         2017-09-30
# 2                                         2018-03-31
# 3                                         2018-03-31
# 4                                         2018-03-31
#
#   companies_house_company_profile.accounts.last_accounts.period_end_on  \
# 0                                         2018-06-30
# 1                                         2017-09-30
# 2                                         2018-03-31
# 3                                         2018-03-31
# 4                                         2018-03-31
#
#   companies_house_company_profile.accounts.last_accounts.period_start_on  \
# 0                                         2017-07-01
# 1                                         2016-10-01
# 2                                         2017-04-01
# 3                                         2017-04-01
# 4                                         2017-04-01
#
#   companies_house_company_profile.accounts.last_accounts.type  \
# 0                                              group
# 1                                       micro-entity
# 2                                              group
# 3                                              group
# 4                                              group
#
#   companies_house_company_profile.accounts.next_accounts.due_on  ...  \
# 0                                         2019-12-31             ...
# 1                                         2019-06-30             ...
# 2                                         2019-12-31             ...
# 3                                         2019-12-31             ...
# 4                                         2019-12-31             ...
#
#      owler_company_premium.perm_id  \
# 0  https://permid.org/1-4295897304
# 1
# 2
# 3  https://permid.org/1-4296446788
# 4
#
#                    owler_company_premium.profile_url  \
# 0  https://www.owler.com/iaApp/2298926/aberdeen-f...
# 1
# 2
# 3  https://www.owler.com/iaApp/280154/edringtongr...
# 4  https://www.owler.com/iaApp/1836466/callbakolo...
#
#   owler_company_premium.revenue owler_company_premium.short_name  \
# 0                                         Aberdeen Football Club
# 1
# 2
# 3                      24876417                   Edringtongroup
# 4                                                 Callbakolondon
#
#   owler_company_premium.stock.exchange  owler_company_premium.stock.ticker  \
# 0
# 1
# 2
# 3
# 4
#
#    owler_company_premium.twitter_link   owler_company_premium.website  \
# 0       http://twitter.com/AberdeenFC            http://www.afc.co.uk
# 1
# 2
# 3                                      http://www.edringtongroup.com/
# 4                                           http://callbakolondon.com
#
#   owler_company_premium.youtube_link  \
# 0
# 1
# 2
# 3
# 4
#
#                          owler_company_premium.error
# 0
# 1  type: insufficient_input , message: Inputs are...
# 2  type: insufficient_input , message: Inputs are...
# 3
# 4
#
# [5 rows x 23039 columns]

# %% [markdown]
# #### Run Matchdeck And Merge Results

# %%
try:
    matchdeck_input = results[results['matchdeck_search.id'].isna() == False][['matchdeck_search.client_id','matchdeck_search.id']]
    matchdeck_input.rename(columns = {'matchdeck_search.client_id':'client_id',
                               'matchdeck_search.id':'id'}, inplace = True)
    matchdeck_results = analytics.enrich_and_download(['matchdeck_details'], matchdeck_input, validate=False)
    results = pd.merge(results, matchdeck_results, how = 'left',left_on = 'client_id', right_on = 'matchdeck_details.client_id')
except:
    print('No company found for matchdeck')
# Out:
# No company found for matchdeck

# %%
results.head()
# Out:
#   company_number  companies_house_company_profile.row_id  client_id  \
# 0       SC005364                                       0          0
# 1       09797821                                       1          1
# 2       09631707                                       2          2
# 3       SC036374                                       3          3
# 4       08802727                                       4          4
#
#    companies_house_company_profile.accounts.accounting_reference_date.day  \
# 0                                                 30
# 1                                                 30
# 2                                                 31
# 3                                                 31
# 4                                                 31
#
#    companies_house_company_profile.accounts.accounting_reference_date.month  \
# 0                                                  6
# 1                                                  9
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#   companies_house_company_profile.accounts.last_accounts.made_up_to  \
# 0                                         2018-06-30
# 1                                         2017-09-30
# 2                                         2018-03-31
# 3                                         2018-03-31
# 4                                         2018-03-31
#
#   companies_house_company_profile.accounts.last_accounts.period_end_on  \
# 0                                         2018-06-30
# 1                                         2017-09-30
# 2                                         2018-03-31
# 3                                         2018-03-31
# 4                                         2018-03-31
#
#   companies_house_company_profile.accounts.last_accounts.period_start_on  \
# 0                                         2017-07-01
# 1                                         2016-10-01
# 2                                         2017-04-01
# 3                                         2017-04-01
# 4                                         2017-04-01
#
#   companies_house_company_profile.accounts.last_accounts.type  \
# 0                                              group
# 1                                       micro-entity
# 2                                              group
# 3                                              group
# 4                                              group
#
#   companies_house_company_profile.accounts.next_accounts.due_on  ...  \
# 0                                         2019-12-31             ...
# 1                                         2019-06-30             ...
# 2                                         2019-12-31             ...
# 3                                         2019-12-31             ...
# 4                                         2019-12-31             ...
#
#      owler_company_premium.perm_id  \
# 0  https://permid.org/1-4295897304
# 1
# 2
# 3  https://permid.org/1-4296446788
# 4
#
#                    owler_company_premium.profile_url  \
# 0  https://www.owler.com/iaApp/2298926/aberdeen-f...
# 1
# 2
# 3  https://www.owler.com/iaApp/280154/edringtongr...
# 4  https://www.owler.com/iaApp/1836466/callbakolo...
#
#   owler_company_premium.revenue owler_company_premium.short_name  \
# 0                                         Aberdeen Football Club
# 1
# 2
# 3                      24876417                   Edringtongroup
# 4                                                 Callbakolondon
#
#   owler_company_premium.stock.exchange  owler_company_premium.stock.ticker  \
# 0
# 1
# 2
# 3
# 4
#
#    owler_company_premium.twitter_link   owler_company_premium.website  \
# 0       http://twitter.com/AberdeenFC            http://www.afc.co.uk
# 1
# 2
# 3                                      http://www.edringtongroup.com/
# 4                                           http://callbakolondon.com
#
#   owler_company_premium.youtube_link  \
# 0
# 1
# 2
# 3
# 4
#
#                          owler_company_premium.error
# 0
# 1  type: insufficient_input , message: Inputs are...
# 2  type: insufficient_input , message: Inputs are...
# 3
# 4
#
# [5 rows x 23039 columns]

# %% [markdown]
# # Clean Output For Analysis - Remove Empty Columns, Errors, Row ID and Input Columns

# %%
results.drop(columns = [column for column in results.columns if 'error' in column or 'inputs' in column or 'row_id' in column or ('client_id' in column and column != 'client_id')], inplace = True)
results.replace([''], [None], inplace =True)
results.dropna(axis = 1, thresh = 1, inplace = True)

# %% [markdown]
# # Display Number of Columns Returned for Each Vendor

# %%
output_columns = sorted([column.split('.')[0] for column in results.columns if 'client_id' != column and 'company_number' != column])
vendor_count = Counter(output_columns)
for vendor in all_providers:
    if vendor not in vendor_count.keys():
        vendor_count[vendor] = 0
vendor_count
# Out:
# Counter({'acuris_business_search': 14213,
#          'companies_house_company_officers': 506,
#          'companies_house_company_profile': 44,
#          'duedil_company_charges': 86,
#          'duedil_company_group_parents': 6,
#          'duedil_company_group_subsidiaries': 27,
#          'duedil_company_officers': 245,
#          'duedil_company_related_companies': 116,
#          'duedil_company_vitals': 34,
#          'duedil_find_company': 75,
#          'globaldatabase_company_details': 12,
#          'globaldatabase_find_companies': 5,
#          'matchdeck_search': 2,
#          'opencorporates_companies_search': 829,
#          'orb_search': 140,
#          'owler_company_premium': 19,
#          'pipl_premium_search': 12,
#          'matchdeck_details': 0})

# %% [markdown]
# # Display Final Results and Save to Local Folder

# %%
results.head()
# Out:
#   company_number  client_id  \
# 0       SC005364          0
# 1       09797821          1
# 2       09631707          2
# 3       SC036374          3
# 4       08802727          4
#
#    companies_house_company_profile.accounts.accounting_reference_date.day  \
# 0                                                 30
# 1                                                 30
# 2                                                 31
# 3                                                 31
# 4                                                 31
#
#    companies_house_company_profile.accounts.accounting_reference_date.month  \
# 0                                                  6
# 1                                                  9
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#   companies_house_company_profile.accounts.last_accounts.made_up_to  \
# 0                                         2018-06-30
# 1                                         2017-09-30
# 2                                         2018-03-31
# 3                                         2018-03-31
# 4                                         2018-03-31
#
#   companies_house_company_profile.accounts.last_accounts.period_end_on  \
# 0                                         2018-06-30
# 1                                         2017-09-30
# 2                                         2018-03-31
# 3                                         2018-03-31
# 4                                         2018-03-31
#
#   companies_house_company_profile.accounts.last_accounts.period_start_on  \
# 0                                         2017-07-01
# 1                                         2016-10-01
# 2                                         2017-04-01
# 3                                         2017-04-01
# 4                                         2017-04-01
#
#   companies_house_company_profile.accounts.last_accounts.type  \
# 0                                              group
# 1                                       micro-entity
# 2                                              group
# 3                                              group
# 4                                              group
#
#   companies_house_company_profile.accounts.next_accounts.due_on  \
# 0                                         2019-12-31
# 1                                         2019-06-30
# 2                                         2019-12-31
# 3                                         2019-12-31
# 4                                         2019-12-31
#
#    companies_house_company_profile.accounts.next_accounts.overdue  ...  \
# 0                                              False               ...
# 1                                              False               ...
# 2                                              False               ...
# 3                                              False               ...
# 4                                              False               ...
#
#   owler_company_premium.industries[0].industry owler_company_premium.is_hit  \
# 0                 Travel, Recreation & Leisure                         true
# 1                                         None                         None
# 2                                         None                         None
# 3                 Travel, Recreation & Leisure                         true
# 4                                         None                         true
#
#                       owler_company_premium.logo_url  \
# 0  https://s3.amazonaws.com/owler-image/logo/aber...
# 1                                               None
# 2                                               None
# 3  https://s3.amazonaws.com/owler-image/logo/edri...
# 4  https://s3.amazonaws.com/owler-image/logo/bako...
#
#       owler_company_premium.name    owler_company_premium.perm_id  \
# 0     Aberdeen Football Club Plc  https://permid.org/1-4295897304
# 1                           None                             None
# 2                           None                             None
# 3            The Edrington Group  https://permid.org/1-4296446788
# 4  Bako South Eastern Wholesaler                             None
#
#                    owler_company_premium.profile_url  \
# 0  https://www.owler.com/iaApp/2298926/aberdeen-f...
# 1                                               None
# 2                                               None
# 3  https://www.owler.com/iaApp/280154/edringtongr...
# 4  https://www.owler.com/iaApp/1836466/callbakolo...
#
#   owler_company_premium.revenue owler_company_premium.short_name  \
# 0                          None           Aberdeen Football Club
# 1                          None                             None
# 2                          None                             None
# 3                      24876417                   Edringtongroup
# 4                          None                   Callbakolondon
#
#   owler_company_premium.twitter_link   owler_company_premium.website
# 0      http://twitter.com/AberdeenFC            http://www.afc.co.uk
# 1                               None                            None
# 2                               None                            None
# 3                               None  http://www.edringtongroup.com/
# 4                               None       http://callbakolondon.com
#
# [5 rows x 16373 columns]

# %%
results.to_csv('', index = False)
