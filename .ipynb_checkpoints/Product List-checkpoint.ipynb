# %%
from demyst.analytics import Analytics
import pandas as pd

analytics = Analytics()

# %%
# Download 
products = analytics.products()
list(map(lambda product: {'Product Name': product['name'], 'Category' : product['category'], 'Tags' : ", ".join(list(map(lambda tag: tag["name"], product['tags']))), "Website" : product["website"], "Description" : product["description"]}}, products))
# Out:
# [{'Product Name': 'clear_business_search'},
#  {'Product Name': 'email_age'},
#  {'Product Name': 'forbes'},
#  {'Product Name': 'google_latlon'},
#  {'Product Name': 'info_connect_individual'},
#  {'Product Name': 'infutor_id_validation_plus'},
#  {'Product Name': 'infutor_phone_owner_id_validation'},
#  {'Product Name': 'infutor_property_append'},
#  {'Product Name': 'infutor_standard_reverse_phone_append'},
#  {'Product Name': 'infutor_vehicle_append'},
#  {'Product Name': 'json_whois'},
#  {'Product Name': 'rap_leaf'},
#  {'Product Name': 'white_pages_pro'},
#  {'Product Name': 'white_pages_pro_find_person'},
#  {'Product Name': 'white_pages_pro_reverse_phone'},
#  {'Product Name': 'infutor_inrichment_true_identity'},
#  {'Product Name': 'equifax_consumer'},
#  {'Product Name': 'lexis_small_biz_risk'},
#  {'Product Name': 'lexis_nexis_enhanced_business'},
#  {'Product Name': 'lexis_nexis_comprehensive_person'},
#  {'Product Name': 'equifax_commercial'},
# ...

# %%
", ".join(["1", "2"])
# Out:
# '1, 2'
